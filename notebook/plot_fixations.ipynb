# %%
#%matplotlib inline

import os
import glob

import numpy as np

import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
files = map(np.load, glob.glob("../export/data/gaze_data_*.npz"))

# %%
sinfo = []
fixations = []

# %%
def get_data():
    try:
        if sinfo and fixations:
            return sinfo, fixations
        
        for f in files:
            sinfo.append(f["session_info"].tolist())     
            fixations.append(f["fixations"])
        
        return sinfo, fixations
    except:
        print("No stored files found.. load from files first")

# %%
def export_plot_data():
    
    sinfo, fixations = get_data()
        
    # dots per inch
    dpi = 100.0
    display_size = (1280, 800)
    
    # determine the figure size in inches
    figsize = (display_size[0]/dpi, 2*display_size[1]/dpi)

    for i, (sinfo, subject_data) in enumerate(zip(sinfo, fixations)):
        
        sid = sinfo.get("sessionId")
        mediafile = sinfo.get("mediaFile")
        
        print("Exporting sid: {}, ({}/{})".format(sid, i+1, len(sinfo)))

        # create a figure
        figure = plt.figure(figsize=figsize, dpi=dpi, constrained_layout=True)
    
        gs = GridSpec(nrows=6, ncols=2, figure=figure)
        
        ax_scan = figure.add_subplot(gs[0:4,:])
        ax_x = figure.add_subplot(gs[4,:])
        ax_y = figure.add_subplot(gs[5,:])

        ax_scan.set_title("sid: {} | mediafile: {} | total samples: {}".format(sid, mediafile, subject_data.shape[0]))
        
        ax_scan.axis([0, display_size[0]/4, 0, display_size[1]/4])

        x, y, d = subject_data.T
        
        d = (d - d.min()) / (d.max() - d.min())
        
        ax_scan.plot(x, y, 'o-', linewidth=.4, markersize=.6)
        ax_scan.scatter(x, y, s=100*d, alpha=.3)
        
        ax_scan.get_xaxis().set_visible(False)
        ax_scan.get_yaxis().set_visible(False)    
        ax_scan.set_aspect("equal")
        
        ax_x.set_title(str(sid) + ' x')
        ax_x.axis([-60, len(x) + 60, 0, display_size[0]/4])
        ax_x.plot(range(len(x)), x, 'o-', linewidth=.4, markersize=.6)
            
        ax_y.set_title(str(sid) + ' y')
        ax_y.axis([-60, len(y) + 60, 0, display_size[1]/4])
        ax_y.plot(range(len(y)), y, 'o-', linewidth=.4, markersize=.6)
        
        mediafile_noext = mediafile.split(".")[0]
        figure.savefig("../export/gazeplot/{}_{}.png".format(mediafile_noext, sid))
        
        del ax_scan
        del ax_x
        del ax_y
        del figure

# %%
plt.ioff()
export_plot_data()
plt.ion()
# Out:
# Exporting sid: 3778, (1/19)
# Exporting sid: 3780, (2/19)
# Exporting sid: 3782, (3/19)
# Exporting sid: 3784, (4/19)
# Exporting sid: 3786, (5/19)
# Exporting sid: 3788, (6/19)
# Exporting sid: 3790, (7/19)
# Exporting sid: 3792, (8/19)
# Exporting sid: 3794, (9/19)
# Exporting sid: 3796, (10/19)
# Exporting sid: 3798, (11/19)
# Exporting sid: 3800, (12/19)
# Exporting sid: 3802, (13/19)
# Exporting sid: 3804, (14/19)
# Exporting sid: 3806, (15/19)
# Exporting sid: 3808, (16/19)
# Exporting sid: 3810, (17/19)
# Exporting sid: 38, (18/19)
# Exporting sid: 398, (19/19)
# Exporting sid: 408, (20/19)
# Exporting sid: 40, (21/19)
# /opt/conda/envs/python2/lib/python2.7/site-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Exporting sid: 420, (22/19)
# Exporting sid: 426, (23/19)
# Exporting sid: 430, (24/19)
# Exporting sid: 4, (25/19)
# Exporting sid: 524, (26/19)
# Exporting sid: 530, (27/19)
# Exporting sid: 542, (28/19)
# Exporting sid: 546, (29/19)
# Exporting sid: 548, (30/19)
# Exporting sid: 652, (31/19)
# Exporting sid: 654, (32/19)
# Exporting sid: 656, (33/19)
# Exporting sid: 658, (34/19)
# Exporting sid: 660, (35/19)
# Exporting sid: 662, (36/19)
# Exporting sid: 664, (37/19)
# Exporting sid: 666, (38/19)
# Exporting sid: 668, (39/19)
# Exporting sid: 670, (40/19)
# Exporting sid: 672, (41/19)
# Exporting sid: 674, (42/19)
# Exporting sid: 676, (43/19)
# Exporting sid: 678, (44/19)
# Exporting sid: 680, (45/19)
# Exporting sid: 682, (46/19)
# Exporting sid: 684, (47/19)
# Exporting sid: 686, (48/19)
# Exporting sid: 688, (49/19)
# Exporting sid: 690, (50/19)
# Exporting sid: 6, (51/19)
# Exporting sid: 782, (52/19)
# Exporting sid: 784, (53/19)
# Exporting sid: 786, (54/19)
# Exporting sid: 788, (55/19)
# Exporting sid: 790, (56/19)
# Exporting sid: 792, (57/19)
# Exporting sid: 794, (58/19)
# Exporting sid: 796, (59/19)
# Exporting sid: 798, (60/19)
# Exporting sid: 800, (61/19)
# Exporting sid: 802, (62/19)
# Exporting sid: 804, (63/19)
# Exporting sid: 806, (64/19)
# Exporting sid: 808, (65/19)
# Exporting sid: 810, (66/19)
# Exporting sid: 812, (67/19)
# Exporting sid: 814, (68/19)
# Exporting sid: 816, (69/19)
# Exporting sid: 818, (70/19)
# Exporting sid: 820, (71/19)
# Exporting sid: 8, (72/19)
# Exporting sid: 920, (73/19)
# Exporting sid: 926, (74/19)
# Exporting sid: 932, (75/19)
# Exporting sid: 944, (76/19)
# Exporting sid: 948, (77/19)
# Exporting sid: 2886, (78/19)
# Exporting sid: 2888, (79/19)
# Exporting sid: 288, (80/19)
# Exporting sid: 2890, (81/19)
# Exporting sid: 2892, (82/19)
# Exporting sid: 2894, (83/19)
# Exporting sid: 2896, (84/19)
# Exporting sid: 2898, (85/19)
# Exporting sid: 28, (86/19)
# Exporting sid: 2900, (87/19)
# Exporting sid: 290, (88/19)
# Exporting sid: 292, (89/19)
# Exporting sid: 294, (90/19)
# Exporting sid: 2992, (91/19)
# Exporting sid: 2994, (92/19)
# Exporting sid: 2996, (93/19)
# Exporting sid: 2998, (94/19)
# Exporting sid: 2, (95/19)
# Exporting sid: 3000, (96/19)
# Exporting sid: 3002, (97/19)
# Exporting sid: 3004, (98/19)
# Exporting sid: 3006, (99/19)
# Exporting sid: 3008, (100/19)
# Exporting sid: 3010, (101/19)
# Exporting sid: 3012, (102/19)
# Exporting sid: 3014, (103/19)
# Exporting sid: 3016, (104/19)
# Exporting sid: 3018, (105/19)
# Exporting sid: 3020, (106/19)
# Exporting sid: 3022, (107/19)
# Exporting sid: 3024, (108/19)
# Exporting sid: 3026, (109/19)
# Exporting sid: 3028, (110/19)
# Exporting sid: 3030, (111/19)
# Exporting sid: 30, (112/19)
# Exporting sid: 3122, (113/19)
# Exporting sid: 3124, (114/19)
# Exporting sid: 3126, (115/19)
# Exporting sid: 3128, (116/19)
# Exporting sid: 3130, (117/19)
# Exporting sid: 3132, (118/19)
# Exporting sid: 3134, (119/19)
# Exporting sid: 3136, (120/19)
# Exporting sid: 3138, (121/19)
# Exporting sid: 3140, (122/19)
# Exporting sid: 3142, (123/19)
# Exporting sid: 3144, (124/19)
# Exporting sid: 3146, (125/19)
# Exporting sid: 3148, (126/19)
# Exporting sid: 3150, (127/19)
# Exporting sid: 3154, (128/19)
# Exporting sid: 3156, (129/19)
# Exporting sid: 3158, (130/19)
# Exporting sid: 3160, (131/19)
# Exporting sid: 32, (132/19)
# Exporting sid: 3382, (133/19)
# Exporting sid: 3384, (134/19)
# Exporting sid: 3386, (135/19)
# Exporting sid: 3388, (136/19)
# Exporting sid: 3390, (137/19)
# Exporting sid: 3392, (138/19)
# Exporting sid: 3394, (139/19)
# Exporting sid: 3396, (140/19)
# Exporting sid: 3398, (141/19)
# Exporting sid: 3400, (142/19)
# Exporting sid: 3402, (143/19)
# Exporting sid: 3404, (144/19)
# Exporting sid: 3406, (145/19)
# Exporting sid: 3408, (146/19)
# Exporting sid: 3410, (147/19)
# Exporting sid: 3412, (148/19)
# Exporting sid: 3414, (149/19)
# Exporting sid: 3416, (150/19)
# Exporting sid: 3418, (151/19)
# Exporting sid: 3420, (152/19)
# Exporting sid: 34, (153/19)
# Exporting sid: 3512, (154/19)
# Exporting sid: 3514, (155/19)
# Exporting sid: 3516, (156/19)
# Exporting sid: 3518, (157/19)
# Exporting sid: 3520, (158/19)
# Exporting sid: 3522, (159/19)
# Exporting sid: 3524, (160/19)
# Exporting sid: 3526, (161/19)
# Exporting sid: 3528, (162/19)
# Exporting sid: 3530, (163/19)
# Exporting sid: 3532, (164/19)
# Exporting sid: 3534, (165/19)
# Exporting sid: 3536, (166/19)
# Exporting sid: 3538, (167/19)
# Exporting sid: 3540, (168/19)
# Exporting sid: 3542, (169/19)
# Exporting sid: 3544, (170/19)
# Exporting sid: 3546, (171/19)
# Exporting sid: 3548, (172/19)
# Exporting sid: 3550, (173/19)
# Exporting sid: 3646, (174/19)
# Exporting sid: 3664, (175/19)
# Exporting sid: 3668, (176/19)
# Exporting sid: 3670, (177/19)
# Exporting sid: 3680, (178/19)
# Exporting sid: 36, (179/19)
# Exporting sid: 3772, (180/19)
# Exporting sid: 3774, (181/19)
# Exporting sid: 3776, (182/19)
# Exporting sid: 2228, (183/19)
# Exporting sid: 2230, (184/19)
# Exporting sid: 2232, (185/19)
# Exporting sid: 2234, (186/19)
# Exporting sid: 2236, (187/19)
# Exporting sid: 2238, (188/19)
# Exporting sid: 2240, (189/19)
# Exporting sid: 2242, (190/19)
# Exporting sid: 2244, (191/19)
# Exporting sid: 2246, (192/19)
# Exporting sid: 2248, (193/19)
# Exporting sid: 2250, (194/19)
# Exporting sid: 22, (195/19)
# Exporting sid: 2342, (196/19)
# Exporting sid: 2352, (197/19)
# Exporting sid: 2354, (198/19)
# Exporting sid: 2358, (199/19)
# Exporting sid: 2376, (200/19)
# Exporting sid: 2472, (201/19)
# Exporting sid: 2474, (202/19)
# Exporting sid: 2476, (203/19)
# Exporting sid: 2478, (204/19)
# Exporting sid: 2480, (205/19)
# Exporting sid: 2482, (206/19)
# Exporting sid: 2484, (207/19)
# Exporting sid: 2486, (208/19)
# Exporting sid: 2488, (209/19)
# Exporting sid: 2490, (210/19)
# Exporting sid: 2492, (211/19)
# Exporting sid: 2494, (212/19)
# Exporting sid: 2496, (213/19)
# Exporting sid: 2498, (214/19)
# Exporting sid: 24, (215/19)
# Exporting sid: 2500, (216/19)
# Exporting sid: 2502, (217/19)
# Exporting sid: 2504, (218/19)
# Exporting sid: 2506, (219/19)
# Exporting sid: 2508, (220/19)
# Exporting sid: 2510, (221/19)
# Exporting sid: 2602, (222/19)
# Exporting sid: 2604, (223/19)
# Exporting sid: 2606, (224/19)
# Exporting sid: 2608, (225/19)
# Exporting sid: 2610, (226/19)
# Exporting sid: 2612, (227/19)
# Exporting sid: 2614, (228/19)
# Exporting sid: 2616, (229/19)
# Exporting sid: 2618, (230/19)
# Exporting sid: 2620, (231/19)
# Exporting sid: 2622, (232/19)
# Exporting sid: 2624, (233/19)
# Exporting sid: 2626, (234/19)
# Exporting sid: 2628, (235/19)
# Exporting sid: 262, (236/19)
# Exporting sid: 2630, (237/19)
# Exporting sid: 2632, (238/19)
# Exporting sid: 2634, (239/19)
# Exporting sid: 2636, (240/19)
# Exporting sid: 2638, (241/19)
# Exporting sid: 2640, (242/19)
# Exporting sid: 264, (243/19)
# Exporting sid: 266, (244/19)
# Exporting sid: 268, (245/19)
# Exporting sid: 26, (246/19)
# Exporting sid: 270, (247/19)
# Exporting sid: 272, (248/19)
# Exporting sid: 2732, (249/19)
# Exporting sid: 2734, (250/19)
# Exporting sid: 2736, (251/19)
# Exporting sid: 2738, (252/19)
# Exporting sid: 2740, (253/19)
# Exporting sid: 2742, (254/19)
# Exporting sid: 2744, (255/19)
# Exporting sid: 2746, (256/19)
# Exporting sid: 2748, (257/19)
# Exporting sid: 274, (258/19)
# Exporting sid: 2750, (259/19)
# Exporting sid: 2752, (260/19)
# Exporting sid: 2754, (261/19)
# Exporting sid: 2756, (262/19)
# Exporting sid: 2758, (263/19)
# Exporting sid: 2760, (264/19)
# Exporting sid: 2762, (265/19)
# Exporting sid: 2764, (266/19)
# Exporting sid: 2766, (267/19)
# Exporting sid: 2768, (268/19)
# Exporting sid: 276, (269/19)
# Exporting sid: 2770, (270/19)
# Exporting sid: 278, (271/19)
# Exporting sid: 280, (272/19)
# Exporting sid: 282, (273/19)
# Exporting sid: 284, (274/19)
# Exporting sid: 2862, (275/19)
# Exporting sid: 2864, (276/19)
# Exporting sid: 2866, (277/19)
# Exporting sid: 2868, (278/19)
# Exporting sid: 286, (279/19)
# Exporting sid: 2870, (280/19)
# Exporting sid: 2872, (281/19)
# Exporting sid: 2874, (282/19)
# Exporting sid: 2876, (283/19)
# Exporting sid: 2878, (284/19)
# Exporting sid: 2880, (285/19)
# Exporting sid: 2882, (286/19)
# Exporting sid: 2884, (287/19)
# Exporting sid: 1058, (288/19)
# Exporting sid: 1060, (289/19)
# Exporting sid: 1062, (290/19)
# Exporting sid: 1064, (291/19)
# Exporting sid: 1066, (292/19)
# Exporting sid: 1068, (293/19)
# Exporting sid: 10, (294/19)
# Exporting sid: 1172, (295/19)
# Exporting sid: 1174, (296/19)
# Exporting sid: 1176, (297/19)
# Exporting sid: 1178, (298/19)
# Exporting sid: 1180, (299/19)
# Exporting sid: 1182, (300/19)
# Exporting sid: 1184, (301/19)
# Exporting sid: 1186, (302/19)
# Exporting sid: 1188, (303/19)
# Exporting sid: 1190, (304/19)
# Exporting sid: 1192, (305/19)
# Exporting sid: 1194, (306/19)
# Exporting sid: 1196, (307/19)
# Exporting sid: 1198, (308/19)
# Exporting sid: 1202, (309/19)
# Exporting sid: 1204, (310/19)
# Exporting sid: 1206, (311/19)
# Exporting sid: 1208, (312/19)
# Exporting sid: 1210, (313/19)
# Exporting sid: 12, (314/19)
# Exporting sid: 132, (315/19)
# Exporting sid: 142, (316/19)
# Exporting sid: 14, (317/19)
# Exporting sid: 152, (318/19)
# Exporting sid: 1562, (319/19)
# Exporting sid: 1586, (320/19)
# Exporting sid: 1588, (321/19)
# Exporting sid: 1592, (322/19)
# Exporting sid: 1598, (323/19)
# Exporting sid: 160, (324/19)
# Exporting sid: 166, (325/19)
# Exporting sid: 1692, (326/19)
# Exporting sid: 1694, (327/19)
# Exporting sid: 1696, (328/19)
# Exporting sid: 1698, (329/19)
# Exporting sid: 16, (330/19)
# Exporting sid: 1700, (331/19)
# Exporting sid: 1702, (332/19)
# Exporting sid: 1704, (333/19)
# Exporting sid: 1706, (334/19)
# Exporting sid: 1708, (335/19)
# Exporting sid: 1710, (336/19)
# Exporting sid: 1712, (337/19)
# Exporting sid: 1714, (338/19)
# Exporting sid: 1716, (339/19)
# Exporting sid: 1718, (340/19)
# Exporting sid: 1720, (341/19)
# Exporting sid: 1722, (342/19)
# Exporting sid: 1724, (343/19)
# Exporting sid: 1726, (344/19)
# Exporting sid: 1728, (345/19)
# Exporting sid: 1730, (346/19)
# Exporting sid: 18, (347/19)
# Exporting sid: 1952, (348/19)
# Exporting sid: 1954, (349/19)
# Exporting sid: 1956, (350/19)
# Exporting sid: 1958, (351/19)
# Exporting sid: 1960, (352/19)
# Exporting sid: 1962, (353/19)
# Exporting sid: 1964, (354/19)
# Exporting sid: 1966, (355/19)
# Exporting sid: 1968, (356/19)
# Exporting sid: 1970, (357/19)
# Exporting sid: 1972, (358/19)
# Exporting sid: 1974, (359/19)
# Exporting sid: 1976, (360/19)
# Exporting sid: 1978, (361/19)
# Exporting sid: 1980, (362/19)
# Exporting sid: 1982, (363/19)
# Exporting sid: 2082, (364/19)
# Exporting sid: 2084, (365/19)
# Exporting sid: 2086, (366/19)
# Exporting sid: 2088, (367/19)
# Exporting sid: 2090, (368/19)
# Exporting sid: 2092, (369/19)
# Exporting sid: 2094, (370/19)
# Exporting sid: 2096, (371/19)
# Exporting sid: 2098, (372/19)
# Exporting sid: 20, (373/19)
# Exporting sid: 2100, (374/19)
# Exporting sid: 2102, (375/19)
# Exporting sid: 2104, (376/19)
# Exporting sid: 2106, (377/19)
# Exporting sid: 2108, (378/19)
# Exporting sid: 2110, (379/19)
# Exporting sid: 2112, (380/19)
# Exporting sid: 2114, (381/19)
# Exporting sid: 2116, (382/19)
# Exporting sid: 2118, (383/19)
# Exporting sid: 2120, (384/19)
# Exporting sid: 2212, (385/19)
# Exporting sid: 2214, (386/19)
# Exporting sid: 2216, (387/19)
# Exporting sid: 2218, (388/19)
# Exporting sid: 2220, (389/19)
# Exporting sid: 2222, (390/19)
# Exporting sid: 2224, (391/19)
# Exporting sid: 2226, (392/19)
# Exporting sid: 1042, (393/19)
# Exporting sid: 1044, (394/19)
# Exporting sid: 1046, (395/19)
# Exporting sid: 1048, (396/19)
# Exporting sid: 1050, (397/19)
# Exporting sid: 1052, (398/19)
# Exporting sid: 1054, (399/19)
# Exporting sid: 1056, (400/19)
